# %%
import pandas as pd
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

# %%
data = pd.read_csv('./finalapi.csv')
data.head()
# Out:
#    AGENCY_ID  PRIMARY_AGENCY_ID   PROD_ABBR PROD_LINE STATE_ABBR  \
# 0          3                  3  BOILERMACH        CL         IN
# 1          3                  3  BOILERMACH        CL         IN
# 2          3                  3  BOILERMACH        CL         IN
# 3          3                  3  BOILERMACH        CL         IN
# 4          3                  3  BOILERMACH        CL         IN
#
#    STAT_PROFILE_DATE_YEAR  RETENTION_POLY_QTY  POLY_INFORCE_QTY  \
# 0                    2005                   0                 0
# 1                    2006                   0                 0
# 2                    2007                   0                 0
# 3                    2008                   0                 0
# 4                    2009                   0                 0
#
#    PREV_POLY_INFORCE_QTY  NB_WRTN_PREM_AMT  ...  PL_BOUND_CT_ELINKS  \
# 0                      0              40.0  ...                   0
# ...

# %%
correlation_coeff, p_value = stats.pearsonr(data['WRTN_PREM_AMT'], data['PRD_INCRD_LOSSES_AMT'])

descriptive_stats = data.describe()

descriptive_stats
# Out:
#           AGENCY_ID  PRIMARY_AGENCY_ID  STAT_PROFILE_DATE_YEAR  \
# count  29551.000000       29551.000000            29551.000000
# mean     700.799262       22022.114243             2010.096274
# std      376.698830       39398.981263                3.150683
# min        3.000000           3.000000             2005.000000
# 25%      456.000000         604.000000             2007.000000
# 50%      702.000000        1193.000000             2010.000000
# 75%      983.000000        8497.000000             2013.000000
# max     1414.000000       99999.000000             2015.000000
#
#        RETENTION_POLY_QTY  POLY_INFORCE_QTY  PREV_POLY_INFORCE_QTY  \
# count        29551.000000      29551.000000           29551.000000
# mean           159.019018        175.603533            6193.239315
# std            774.518071        829.657592           23736.701731
# min              0.000000          0.000000               0.000000
# ...

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='WRTN_PREM_AMT', y='PRD_INCRD_LOSSES_AMT')
plt.title('Written Premium vs Incurred Losses')
plt.xlabel('Written Premium Amount')
plt.ylabel('Incurred Losses Amount')
# Out:
# Text(0, 0.5, 'Incurred Losses Amount')

# %%
print("\nCorrelation Analysis Results:")
print(f"Pearson correlation coefficient: {correlation_coeff:.4f}")
print(f"P-value: {p_value:.4f}")
print("\nDescriptive Statistics:")
print(descriptive_stats)

if p_value < 0.05:
    print("\nResult: Reject the null hypothesis")
    print("There is significant evidence of correlation between written premium and incurred losses")
else:
    print("\nResult: Fail to reject the null hypothesis")
    print("There is insufficient evidence of correlation between written premium and incurred losses")
# Out:
# Correlation Analysis Results:
# Pearson correlation coefficient: 0.6057
# P-value: 0.0000
#
# Descriptive Statistics:
#           AGENCY_ID  PRIMARY_AGENCY_ID  STAT_PROFILE_DATE_YEAR  \
# count  29551.000000       29551.000000            29551.000000
# mean     700.799262       22022.114243             2010.096274
# std      376.698830       39398.981263                3.150683
# min        3.000000           3.000000             2005.000000
# 25%      456.000000         604.000000             2007.000000
# 50%      702.000000        1193.000000             2010.000000
# 75%      983.000000        8497.000000             2013.000000
# max     1414.000000       99999.000000             2015.000000
#
#        RETENTION_POLY_QTY  POLY_INFORCE_QTY  PREV_POLY_INFORCE_QTY  \
# count        29551.000000      29551.000000           29551.000000
# mean           159.019018        175.603533            6193.239315
# std            774.518071        829.657592           23736.701731
# ...
