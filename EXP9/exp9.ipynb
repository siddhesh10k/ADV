# %% [markdown]
# <style type="text/css">
# .tf  {border-collapse:collapse;border-spacing:0;width:100%}
# .tf td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tf th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 5px;word-break:normal;}
# .tf .tg-0pky{border-color:inherit;text-align:left;vertical-align:top}
# .col1 { width: 20%;}
# .col2 { width: 80%;}
# </style>
# <table class="tf">
# <thead>
#   <tr>
#     <th class="tg-0pky col1">Name</th>
#     <th class="tg-0pky col2">Siddhesh Kirdat</th>
#   </tr>
# </thead>
# <tbody>
#   <tr>
#     <td class="tg-0pky col1">UID No.</td>
#     <td class="tg-0pky col2">2021300064</td>
#   </tr>
#   <tr>
#     <td class="tg-0pky col1">Course</td>
#     <td class="tg-0pky col2">Advanced Data Visualization</td>
#   </tr>
# </tbody>
# </table>

# %% [markdown]
# ## <p style="text-align:center;font-weight:500;">Experiment 9</p>
# <style type="text/css">
# .tg  {border-collapse:collapse;border-spacing:0;width:100%}
# .tg td{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   overflow:hidden;padding:10px 5px;word-break:normal;}
# .tg th{border-color:black;border-style:solid;border-width:1px;font-family:Arial, sans-serif;font-size:14px;
#   font-weight:normal;overflow:hidden;padding:10px 10px;word-break:normal;}
# .tg .tg-0pky{border-color:inherit;text-align:left;vertical-align:top;}
# .col1 { width: 20%;}
# .col2 { width: 80%;}
# </style>
# <table class="tg">
# <thead>
#   <tr>
#     <th class="tg-0pky col1">Aim</th>
#     <th class="tg-0pky col2">
#       Design Big Data Dashboards using Tableau on the dataset - Women empowerment / Gender participation
#       <br>
#       1. Basic - Bar chart, Pie chart, Histogram, Time line chart, Scatter plot, Bubble plot
#       <br>
#       2. Advanced - Word chart, Box and whisker plot, Violin plot, Regression plot (linear and nonlinear), 3D chart, Jitter
#       <br>
#       3. Write observations from each chart
#       <br>
#     </th>
#   </tr>
# </thead>
# </table>

# %% [markdown]
# ### 1. Importing Libraries and Dataset

# %%
import pandas as pd

# %% [markdown]
# ### 2. Data Preprocessing

# %%
data = pd.read_csv('../Datasets/women_empowerment_index.csv')
print(data.shape)
data.head()
# Out:
# (114, 7)
#      Country  Women's Empowerment Index (WEI) - 2022  \
# 0  Australia                                   0.805
# 1    Belgium                                   0.801
# 2    Denmark                                   0.804
# 3    Iceland                                   0.816
# 4     Norway                                   0.802
#
#   Women's Empowerment Group - 2022  Global Gender Parity Index (GGPI) - 2022  \
# 0                             High                                     0.870
# 1                             High                                     0.869
# 2                             High                                     0.845
# 3                             High                                     0.914
# 4                             High                                     0.887
#
#   Gender Parity Group - 2022 Human Development Group - 2021  \
# 0                       High                      Very high
# 1                       High                      Very high
# 2                       High                      Very high
# 3                       High                      Very high
# 4                       High                      Very high
#
#   Sustainable Development Goal regions
# 0            Australia and New Zealand
# 1          Europe and Northern America
# 2          Europe and Northern America
# 3          Europe and Northern America
# 4          Europe and Northern America

# %% [markdown]
# <p style="page-break-after:always;"></p>

# %% [markdown]
# ### 3. Tableau Dashboard

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Conclusion
# In this experiment, we learned how to design Big Data Dashboards using Tableau on a given dataset
